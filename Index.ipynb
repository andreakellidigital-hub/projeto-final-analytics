# %% [markdown]
# <a href="https://colab.research.google.com/github/andreakellidigital-hub/projeto-final-analytics/blob/main/Index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Trabalho Final — Data Analytics: Análise de Dados para Tomada de Decisão**
# **Professor:** André Salerno • **Aluna:** Andréa Kelli Magalhães
#
# > **Propósito do notebook**
# > Organizar, demonstrar e **comprovar** (com código) os principais conceitos vistos na disciplina, aplicando-os a um **estudo de caso real** do meu dia a dia.
#
# ---
#
# ## 🔎 Sumário
# 1. Dados da Matéria e Professor
# 2. Dados Pessoais
# 3. Objetivo
# 4. Habilidades (Hard & Soft)
# 5. Resumo
# 6. Hobbies
# 7. Introdução ao Python
# 8. Pandas na prática
# 9. Estatística (descrições + gráficos)
# 10. Estratégia
# 11. GitHub
# 12. Estudo de Caso - Gestão no dia a dia
# 13. Conclusões

# %% [markdown]
# # ✨ Andréa Kelli ✨
#
# **📧 Email:** [andreakellidigital@gmail.com](mailto:andreakellidigital@gmail.com)
# **🔗 LinkedIn:** [linkedin.com/in/andreakelli](https://www.linkedin.com/in/andreakelli)
# **📸 Instagram:** [@andreakelli1](https://www.instagram.com/andreakelli1)
#
# ---
#
# #<font color="blue"> 2. Dados Pessoais</font>
#
# **Nome:** Andréa Kelli
# **Email:** [andreakellidigital@gmail.com](mailto:andreakellidigital@gmail.com)
# **LinkedIn:** [linkedin.com/in/andreakelli](https://www.linkedin.com/in/andreakelli)
# **Instagram:** [@andreakelli1](https://www.instagram.com/andreakelli1)
#
# ---
#
# #<font color="blue"> 3. Objetivo</font>
#
# Meu objetivo profissional é aplicar minhas habilidades e conhecimentos em **marketing digital**, **redes sociais** e **inteligência artificial** para ajudar empresas a crescerem de forma sustentável e pessoas a se conectarem com novas oportunidades. Busco sempre evoluir em técnicas de **estratégia**, **análise de dados** e **criação de conteúdos digitais**, utilizando ferramentas como **IA Generativa**, **plataformas de design**, e **automação de processos**.
#
# ---
#
# #<font color="blue"> 4. Habilidades</font>
#
# <font color="blue"> 4.1 Hard Skills</font>
#
# - 📈 **Marketing Digital**: Do planejamento à gestão de redes sociais como Instagram, TikTok, LinkedIn e WhatsApp Business.
# - ✍️ **Copywriting & Storytelling**: Criando narrativas envolventes para vendas, turismo e experiências culturais memoráveis.
# - 🎨 **Design Digital**: Desenvolvendo materiais visuais impactantes no Canva para formatos digitais e impressos.
# - 🤖 **Inteligência Artificial**: Aplicando ferramentas como ChatGPT, Gemini, Veo3 e automações para gerar conteúdo, vídeos e imagens inovadoras.
# - ⚙️ **Automação de Marketing**: Otimizando processos de divulgação, atendimento e vendas com IA e plataformas digitais.
# - 🤝 **Consultoria & Mentoria**: Diagnosticando, planejando e capacitando através de workshops e mentorias.
# - 🎪 **Eventos & Feiras**: Orquestrando experiências interativas e ativando marcas em eventos e feiras.
#
# <font color="blue"> 4.2 Soft Skills</font>
#
# - 🌟 **Liderança Colaborativa**: Unindo equipes e empresários em busca de objetivos comuns e resultados expressivos.
# - 🗣️ **Comunicação Estratégica**: Transmitindo ideias com clareza e persuasão em diversas plataformas.
# - ✨ **Criatividade & Inovação**: Gerando soluções originais em marketing, turismo e IA aplicada a negócios.
# - 🗓️ **Organização & Gestão do Tempo**: Gerenciando múltiplos projetos com foco em prazos e entregas de alta qualidade.
# - 👋 **Relacionamento Interpessoal**: Construindo conexões sólidas baseadas em confiança e engajamento.
# - 🌱 **Adaptabilidade**: Navegando com flexibilidade entre a inovação tecnológica e a riqueza da tradição cultural.
# - 🔭 **Visão Estratégica**: Analisando cenários para identificar oportunidades e direcionar o crescimento sustentável.
# - 🤔 **Resolução de Problemas**: Encontrando soluções práticas e assertivas para desafios do mercado.
#
# ---
#
# #<font color="blue"> 5. Resumo</font>
#
# Sou consultora especializada em **Marketing Digital, Inteligência Artificial e Turismo de Experiência**. Minhas competências técnicas abrangem planejamento estratégico, gestão de redes sociais, copywriting, storytelling, design digital e automação de marketing, com domínio em ferramentas de IA Generativa e Canva. Minhas soft skills em **liderança colaborativa**, **comunicação estratégica**, **criatividade**, **organização** e **visão estratégica** me permitem desenvolver projetos, mentorias e eventos de forma **inovadora**, criando pontes entre pessoas, negócios e experiências inesquecíveis.

# %%
# 📌 Nuvem de Palavras - Hard & Soft Skills com cores vibrantes (Amarelo, Azul, Roxo, Rosa)

from wordcloud import WordCloud
import matplotlib.pyplot as plt
import random

# Função para escolher cores personalizadas
def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    cores = ["#FFD700",  # Amarelo vibrante
             "#1E90FF",  # Azul forte
             "#8A2BE2",  # Roxo intenso
             "#FF1493"]  # Rosa vibrante (Deep Pink)
    return random.choice(cores)

# Hard e Soft Skills (com destaques repetidos)
texto_skills = """
MarketingDigital RedesSociais Instagram TikTok LinkedIn WhatsAppBusiness
Copywriting Storytelling NarrativasVendas Turismo ExperienciasCulturais
DesignDigital Canva MateriaisVisuais Impacto
InteligenciaArtificial InteligenciaArtificial InteligenciaArtificial
ChatGPT Gemini Veo3 Automatizacoes
AutomacaoMarketing Divulgacao Atendimento Vendas PlataformasDigitais
Consultoria Mentoria Workshops Diagnostico Planejamento
Eventos Feiras ExperienciasInterativas AtivacaoDeMarcas

LiderancaColaborativa Equipes Empresarios
ComunicacaoEstrategica ComunicacaoEstrategica ComunicacaoEstrategica
Criatividade Criatividade Criatividade Inovacao SolucoesOriginais
Organizacao GestaoDoTempo Projetos Prazos Entregas
RelacionamentoInterpessoal Conexoes Confianca Engajamento
Adaptabilidade InovacaoTecnologica TradicaoCultural
VisaoEstrategica AnaliseCenarios Oportunidades CrescimentoSustentavel
ResolucaoProblemas SolucoesPraticas Assertividade
"""

# Criar a nuvem de palavras
wordcloud = WordCloud(width=1000, height=500,
                      background_color="white",
                      max_font_size=160,
                      color_func=color_func).generate(texto_skills)

# Exibir
plt.figure(figsize=(14,7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("☁️ Minhas Hard & Soft Skills ☁️", fontsize=18, fontweight="bold", color="darkblue")
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

anos = [
    "1996–2000", "2001–2010", "2011–2019",
    "2020–2022", "2022–2025", "2025+"
]
titulos = [
    "As Raízes",
    "Bastidores do Poder e da Cultura",
    "Propósito Desperta",
    "Virada Empreendedora",
    "Rota da Transformação",
    "Nova Era com IA"
]
descricoes = [
    "Banco do Brasil e Governo de Goiás. Atendimento e cerimonial.",
    "Eventos institucionais e culturais: Copa 2014, Comida de Buteco, Governo de Goiás.",
    "Centro Cultural, Parque Marcos Veiga, formação em PNL, idealização de festivais.",
    "Consultora Sebrae e sócia da Maria Bretas. Foco em turismo e desenvolvimento.",
    "Agente da Rota Além das Águas. Experiências turísticas e valorização local.",
    "MBA em IA. Criação do MentorIA AK. Educação e inovação com tecnologia."
]

cores = ['#AEDFF7', '#FFDDC1', '#D2F8D2', '#F9D5E5', '#FFF1BA', '#CAB8FF']
icones = ['🌱', '🎭', '🌟', '🚀', '💧', '🤖']

fig, ax = plt.subplots(figsize=(10, 6))
for i, (ano, titulo, descricao, cor, icone) in enumerate(zip(anos, titulos, descricoes, cores, icones)):
    ax.barh(i, 1, color=cor)
    ax.text(0, i, f"{icone} {ano} - {titulo}\n{descricao}", va='center', fontsize=9)

ax.set_yticks([])
ax.set_xticks([])
ax.invert_yaxis()
ax.set_title("Linha do Tempo Profissional – Andréa Kelli", fontsize=14, weight='bold')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-400055601.py:38: UserWarning: Glyph 127793 (\N{SEEDLING}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-400055601.py:38: UserWarning: Glyph 127917 (\N{PERFORMING ARTS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-400055601.py:38: UserWarning: Glyph 127775 (\N{GLOWING STAR}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-400055601.py:38: UserWarning: Glyph 128640 (\N{ROCKET}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-400055601.py:38: UserWarning: Glyph 128167 (\N{DROPLET}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-400055601.py:38: UserWarning: Glyph 129302 (\N{ROBOT FACE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127793 (\N{SEEDLING}) missing from font(s) DejaVu Sans.
# ...

# %% [markdown]
# #<font color="blue"> 6. Hobbies</font>
#
# 💃 Dançar: Minha forma favorita de recarregar energias e celebrar a vida.
#
# 🥂 Momentos com amigos: Conversas leves, acompanhadas de uma cervejinha ou taça de vinho, porque boas ideias também nascem fora da rotina.
#
# 🎬 Cinéfila de carteirinha: Adoro assistir filmes que inspiram novas perspectivas.
#
# 🤖 Exploradora de IA criativa: Testo constantemente novas ferramentas de inteligência artificial para transformar curiosidade em inovação.

# %% [markdown]
# ----
# #🔎 <font color="blue">Insights que transformam: aprendizados em Data Analytics</font>
# ----

# %% [markdown]
# #<font color="blue"> 7. Introdução Python</font>
#
# Python é uma linguagem de programação de alto nível, simples e versátil, muito utilizada em inteligência artificial e ciência de dados.
# Possui sintaxe clara, grande comunidade e milhares de bibliotecas que facilitam o desenvolvimento rápido.
# Com ela, é possível desde automações simples até projetos avançados em machine learning e deep learning.

# %%
import sys
print(sys.version)
# Out:
# 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]

# %%
sys.version_info
# Out:
# sys.version_info(major=3, minor=12, micro=11, releaselevel='final', serial=0)

# %%
import pandas as pd

# %%
pd.pandas

# %%
# Example of addition
num1 = 10
num2 = 5
sum_result = num1 + num2
print(f"The sum of {num1} and {num2} is: {sum_result}")
# Out:
# The sum of 10 and 5 is: 15

# %%
15-10
# Out:
# 5

# %%
50*5
# Out:
# 250

# %%
100/2
# Out:
# 50.0

# %%
nome = input("Digite seu nome: ")
print (f"Olá, {nome}! Seja bem-vindo(a)")
# Out:
# Digite seu nome: Andréa Kelli
# Olá, Andréa Kelli! Seja bem-vindo(a)

# %%
a = "Andréa"
print (type(a))
# Out:
# <class 'str'>

# %%
b = 10
print (type(b))
# Out:
# <class 'int'>

# %%
c = 10.5
print (type (c))
# Out:
# <class 'float'>

# %%
d = True
print (type(d))
# Out:
# <class 'bool'>

# %%
a = 10
b = 5
soma = a + b
print(soma)
# Out:
# 15

# %%
nome = "Andréa"
Sobrenome = "Kelli"
print (nome + " " + Sobrenome)
# Out:
# Andréa Kelli

# %%
nome = "Andréa"

sobrenome = "Kelli"

nome_completo = f'{nome} {sobrenome}'

print(nome_completo)
# Out:
# Andréa Kelli

# %%
#exemplo de condição e decisão

idade = 18

if idade >= 18:

    print ("Você é maior de idade")
    print ("Você pode dirigir")
else:
    print ("Você é menor de idade")
    print ("Você não pode dirigir")
# Out:
# Você é maior de idade
# Você pode dirigir

# %%
for i in range (5):
  print (i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Lista de tarefas simples em Python
tarefas = ["Estudar Python", "Revisar Machine Learning", "Praticar exercícios"]

for i, tarefa in enumerate(tarefas, start=1):
    print(f"{i}. {tarefa}")
# Out:
# 1. Estudar Python
# 2. Revisar Machine Learning
# 3. Praticar exercícios

# %%
# Example of updating prices using a for loop and if/else
produtos = [
    {"nome": "Produto A", "preco": 100},
    {"nome": "Produto B", "preco": 250},
    {"nome": "Produto C", "preco": 50}
]
print("Preços originais:")
for produto in produtos:
    print(f"{produto['nome']}: R${produto['preco']:.2f}")
# Apply price updates
for produto in produtos:
    if produto["preco"] < 100:
        produto["preco"] *= 1.15  # Increase price by 15% for products under R$100
    elif produto["preco"] >= 100 and produto["preco"] < 200:
        produto["preco"] *= 1.10  # Increase price by 10% for products between R$100 and R$200
    else:
        produto["preco"] *= 1.05  # Increase price by 5% for products R$200 or more
print("\nPreços atualizados:")
for produto in produtos:
    print(f"{produto['nome']}: R${produto['preco']:.2f}")
# Out:
# Preços originais:
# Produto A: R$100.00
# Produto B: R$250.00
# Produto C: R$50.00
#
# Preços atualizados:
# Produto A: R$110.00
# Produto B: R$262.50
# Produto C: R$57.50

# %% [markdown]
# #<font color="blue"> 8. PANDAS</font>
# Pandas é uma biblioteca Python voltada para análise e manipulação de dados, muito usada em ciência de dados.
# Ela oferece estruturas como Series (dados unidimensionais) e DataFrame (tabelas bidimensionais) para organizar informações.
# Com ela é possível ler, transformar, limpar e visualizar dados de forma rápida e eficiente.

# %%
import pandas as pd
df=pd.read_csv("/PassengerId.txt",sep=",")

# %%
df.head (1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
PassengerId_nome_pass = df['Name']
print(PassengerId_nome_pass)
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                  Heikkinen, Miss Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                          Graham, Miss Margaret Edith
# 888              Johnston, Miss Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
PassengerId_duas_colunas = df[['Name', 'Age']]
print(PassengerId_duas_colunas)
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                                Heikkinen, Miss Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                        Graham, Miss Margaret Edith  19.0
# 888            Johnston, Miss Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
len(df)
# Out:
# 891

# %%
len(df.columns)
# Out:
# 12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
smallPassengerId = df.head(10)[["Name", "Age"]]

print(smallPassengerId)
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                              Heikkinen, Miss Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0
# 5                                   Moran, Mr. James   NaN
# 6                            McCarthy, Mr. Timothy J  54.0
# 7                      Palsson, Master Gosta Leonard   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0

# %%
smallPassengerIdFiltered = df[df["Age"] > 30]

print(smallPassengerIdFiltered)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                             Bonnell, Miss Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
drescricao = df.describe()

print(drescricao)
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.iloc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %%
df.iloc [0:10,0:2]
# Out:
#    PassengerId  Survived
# 0            1         0
# 1            2         1
# 2            3         1
# 3            4         1
# 4            5         0
# 5            6         0
# 6            7         0
# 7            8         0
# 8            9         1
# 9           10         1

# %%
drescricao = df.describe()

print(drescricao)
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df = df.rename(columns={'Age': 'Idade', 'Name': 'Nome'})

display(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Nome     Sex  Idade  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0      1
# 2                              Heikkinen, Miss Laina  female   26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0      1
# 4                           Allen, Mr. William Henry    male   35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Nome     Sex  Idade  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
dados1 = {

    'Produto': ['Camiseta', 'Calça', 'Jaqueta', 'Tênis'],

    'Preço': [50, 100, 150, None],

    'Quantidade': [100, 150, 300, None]

}

# %%
print(dados1)
# Out:
# {'Produto': ['Camiseta', 'Calça', 'Jaqueta', 'Tênis'], 'Preço': [50, 100, 150, None], 'Quantidade': [100, 150, 300, None]}

# %%
df1 = pd.DataFrame(dados1)

# Exibindo o DataFrame

print(df1)

print()
# Out:
#     Produto  Preço  Quantidade
# 0  Camiseta   50.0       100.0
# 1     Calça  100.0       150.0
# 2   Jaqueta  150.0       300.0
# 3     Tênis    NaN         NaN

# %%
# Substituir valores ausentes por quinhentos

df1.fillna(500, inplace=True)

print(df1)
# Out:
#     Produto  Preço  Quantidade
# 0  Camiseta   50.0       100.0
# 1     Calça  100.0       150.0
# 2   Jaqueta  150.0       300.0
# 3     Tênis  500.0       500.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a bar chart for quantities
plt.figure(figsize=(8, 6))
sns.barplot(x='Produto', y='Quantidade', data=df1)
plt.title('Quantidade de Produtos')
plt.xlabel('Produto')
plt.ylabel('Quantidade')
plt.show()

# %%
# agrupamento horizontal

import pandas as pd

# DataFrame 1: Produtos

produtos = {

    'Produto': ['Camiseta', 'Calça', 'Jaqueta', 'Tênis'],

    'Preço': [50, 100, 200, 150]

}

df_produtos = pd.DataFrame(produtos)

# DataFrame 2: Vendas

vendas = {

    'Quantidade': [100, 150, 80, 120]

}

df_vendas = pd.DataFrame(vendas)

# Agrupar horizontalmente (adicionar as colunas de df_vendas ao df_produtos)

df_completo = pd.concat([df_produtos, df_vendas], axis=1)

# Exibir o DataFrame resultante

print(df_completo)
print(df_produtos)
print(df_vendas)
# Out:
#     Produto  Preço  Quantidade
# 0  Camiseta     50         100
# 1     Calça    100         150
# 2   Jaqueta    200          80
# 3     Tênis    150         120
#     Produto  Preço
# 0  Camiseta     50
# 1     Calça    100
# 2   Jaqueta    200
# 3     Tênis    150
#    Quantidade
# 0         100
# 1         150
# 2          80
# 3         120

# %% [markdown]
# #<font color="blue"> 9. Estatística</font>

# %% [markdown]
# #### Cálculo da Média
#
# <hr style="border: 1px solid rgba(242, 248, 241, 1); width: 100%; margin: 5px 0;">
#
# A fórmula da média é usada para calcular o valor médio de um conjunto de dados. A fórmula é dada por:
#
# $$
#
# \text{Média} = \frac{\sum_{i=1}^{n} x_i}{n}
#
# $$
#
# Onde:
#
# - $( x_i )$ representa cada valor do conjunto de dados.
#
# - $( n )$ é o número total de elementos.
#
# ### Exemplo:
#
# Se tivermos os seguintes números: 2, 4, 6, 8, 10, a média será:
#
# $$
#
# \text{Média} = \frac{2 + 4 + 6 + 8 + 10}{5} = \frac{30}{5} = 6
#
# $$

# %%
# Média

a = [2, 4, 6, 8, 10]

print(f'Média: {sum(a) / len(a)}')
# Out:
# Média: 6.0

# %%
import statistics as st

print(f'Média: {st.mean(a)}')
# Out:
# Média: 6

# %%
# número ímpar de elementos

b = [1500, 1800, 2000, 2100, 2200, 2400]

print(f'Mediana: {sorted(b)[len(b) // 2] if len(b) % 2 != 0 else (sorted(b)[len(b) // 2 - 1] + sorted(b)[len(b) // 2]) / 2}')
# Out:
# Mediana: 2050.0

# %%
import numpy as np

import pandas as pd

from statistics import mode

notas = [8, 7, 6, 9, 7, 8, 10, 9, 6, 7, 8, 2, 10, 9, 7, 6, 8, 9, 5, 10]

media = np.mean(notas)

mediana = np.median(notas)

moda = mode(notas)

print("Média   :", media)

print("Mediana :", mediana)

print("Moda    :", moda)
# Out:
# Média   : 7.55
# Mediana : 8.0
# Moda    : 8

# %%
amplitude = max(notas) - min(notas)

variancia = np.var(notas, ddof=1)   # ddof=1 → amostral

desvio_padrao = np.std(notas, ddof=1)

cv = desvio_padrao / media

print("Amplitude        :", amplitude)

print("Variância        :", variancia)

print("Desvio Padrão    :", desvio_padrao)

print("Coef. Variação   :", cv)
# Out:
# Amplitude        : 8
# Variância        : 3.8394736842105264
# Desvio Padrão    : 1.9594574974238472
# Coef. Variação   : 0.2595307943607745

# %% [markdown]
# [texto do link](https://)#<font color="blue"> 9. Visualização</font>

# %%
import matplotlib.pyplot as plt

plt.hist(notas, bins=10, edgecolor="black")

plt.title("Histograma de Notas")

plt.xlabel("Notas")

plt.ylabel("Quantidade")

# Salva a imagem (antes do show)

#plt.savefig("../img/histograma_notas.png", dpi=300, bbox_inches="tight")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3939352024.py in <cell line: 0>()
#      11 # Salva a imagem (antes do show)
#      12
# ---> 13 plt.savefig("../img/histograma_notas.png", dpi=300, bbox_inches="tight")
#      14
#      15 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#    1241     # savefig default implementation has no return, so mypy is unhappy
#    1242     # presumably this is here because subclasses can return?
# -> 1243     res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1244     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1245     return res
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3488                 for ax in self.axes:
# ...

# %%
import pandas as pd

df = pd.DataFrame({"Notas": notas})

contagem = df["Notas"].value_counts().sort_index()

contagem.plot(kind="bar", color="skyblue", edgecolor="black")

plt.title("Frequência das Notas")

plt.xlabel("Nota")

plt.ylabel("Quantidade")

# Salva a imagem (antes do show)

#plt.savefig("../img/barras_notas.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
contagem.plot(kind="pie", autopct="%1.1f%%", figsize=(6,6))

plt.title("Proporção de cada Nota")

plt.ylabel("")  # remove label lateral

#plt.savefig("../img/pizza_notas.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# #<font color="blue"> 10. Estratégia</font>
# A estratégia é a etapa inicial do ciclo BPM, onde se definem a visão, objetivos e metas a serem alcançadas pela organização.
# Ela orienta o direcionamento das ações e garante que todas as decisões estejam alinhadas aos resultados esperados.
# É o ponto de partida para transformar dados em insights que guiem o plano e a tomada de decisão.
#
# A estratégia é o ponto de partida da análise de dados para tomada de decisão.
# Envolve:
#
# **Definir objetivos claros** (o que queremos alcançar).
#
# **Estabelecer indicadores de desempenho** (KPIs) para medir progresso.
#
# **Usar dados para embasar planos e evitar decisões apenas intuitivas.**

# %% [markdown]
# **##Exemplo prático no Colab**
#
# Simulação de uma empresa que quer aumentar as vendas em 20%:

# %%
import pandas as pd

# Exemplo de dados de vendas (em milhares)
dados = {
    "Mês": ["Jan", "Fev", "Mar", "Abr", "Mai", "Jun"],
    "Vendas": [100, 120, 130, 115, 140, 160]
}

df = pd.DataFrame(dados)

# Meta estratégica: aumentar vendas em 20%
meta = df["Vendas"].mean() * 1.20

print("Média atual de vendas:", df["Vendas"].mean())
print("Meta estratégica (20% a mais):", meta)

# Monitoramento simples
df["Meta Atingida"] = df["Vendas"] >= meta
df
# Out:
# Média atual de vendas: 127.5
# Meta estratégica (20% a mais): 153.0
#    Mês  Vendas  Meta Atingida
# 0  Jan     100          False
# 1  Fev     120          False
# 2  Mar     130          False
# 3  Abr     115          False
# 4  Mai     140          False
# 5  Jun     160           True

# %% [markdown]
# ##📊**Ciclo Estratégico**

# %% [markdown]
# # **Estratégia**
# A estratégia define a visão e as metas principais.
# Exemplo: aumentar as vendas em **20%** no próximo semestre.
# Isso será a referência para todas as análises e decisões.

# %% [markdown]
# import pandas as pd
# #**Plano**
#
# # Dados fictícios de vendas mensais (em milhares)
# dados = {
#     "Mês": ["Jan", "Fev", "Mar", "Abr", "Mai", "Jun"],
#     "Vendas": [100, 120, 130, 115, 140, 160]
# }
#
# df = pd.DataFrame(dados)
#
# # Meta estratégica: +20% sobre a média atual
# meta = df["Vendas"].mean() * 1.20
# print("Meta estratégica:", round(meta, 2))
# df

# %% [markdown]
# #**Monitoramento / Análise**
# # Verifica mês a mês se a meta foi atingida
# df["Meta Atingida"] = df["Vendas"] >= meta
# df
#
# # Percentual de meses que atingiram a meta
# atingidos = df["Meta Atingida"].mean() * 100
# print(f"Meta atingida em {atingidos:.1f}% dos meses")

# %% [markdown]
# # **Atuação / Ajuste**
# Se a meta não está sendo atingida, sugerir ajustes

# %%
# Percentual de meses que atingiram a meta
atingidos = df["Meta Atingida"].mean() * 100
print(f"Meta atingida em {atingidos:.1f}% dos meses")
# Out:
# Meta atingida em 16.7% dos meses

# %% [markdown]
# #📊 **Visualização: Vendas vs Meta**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(df["Mês"], df["Vendas"], marker="o", label="Vendas")
plt.axhline(y=meta, color="r", linestyle="--", label=f"Meta ({round(meta,1)})")

plt.title("Vendas Mensais x Meta Estratégica")
plt.xlabel("Mês")
plt.ylabel("Vendas (milhares)")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()

# %% [markdown]
# # **Conclusão do Ciclo Estratégico**
#
# O ciclo **Estratégia → Plano → Monitoramento → Ajuste** permite alinhar metas da empresa com decisões baseadas em dados.
#
# ✔ **Estratégia:** Definir objetivo claro (ex: aumentar vendas em 20%).
# ✔ **Plano:** Traduzir o objetivo em metas numéricas e ações práticas.
# ✔ **Monitoramento/Análise:** Acompanhar resultados reais e compará-los com a meta.
# ✔ **Atuação/Ajuste:** Reforçar ações que funcionam ou corrigir falhas quando necessário.
#
# 🔑 Assim, dados deixam de ser apenas registros e se transformam em **insights estratégicos** para melhorar a performance e apoiar a tomada de decisão.

# %% [markdown]
# #<font color="blue"> 11. GitHub</font>
# O GitHub é uma plataforma de hospedagem de código baseada no Git, sistema de controle de versão distribuído.
# Na prática, funciona como um repositório online, onde desenvolvedores armazenam, compartilham e colaboram em projetos de software.
# Com isso, torna-se essencial para o versionamento e organização de código, facilitando o trabalho em equipe e a integração com diversas ferramentas.

# %% [markdown]
# **Conceitos básicos**
# - **Repositório**: onde o código fica armazenado.
# - **Commit**: registro de uma alteração no projeto.
# - **Branch**: linha paralela de desenvolvimento.
# - **Pull Request (PR)**: solicitação de integração de mudanças.
# - **Clone**: cópia local do repositório do GitHub para sua máquina.

# %% [markdown]
# #<font color="blue"> 12. Estudo de Caso</font>
# **Contexto:**
# No meu dia a dia como consultora/empreendedora, percebi a necessidade de [ex.: organizar melhor as interações com clientes / analisar os gastos do mês / medir o engajamento no Instagram].
#
# **Problema:**
# A dificuldade estava em [ex.: não ter uma visão clara dos dados, perder muito tempo em tarefas manuais, dificuldade em gerar insights].
#
# **Solução aplicada:**
# Utilizei [ex.: Python com Pandas / Google Sheets com fórmulas / Power BI / ChatGPT] para organizar e analisar os dados.
#
# **Exemplo:** importei os dados de vendas em um DataFrame, calculei médias semanais e criei um gráfico de tendência.
#
# **Resultado:**
# Consegui [ex.: visualizar quais dias têm mais vendas, identificar produtos mais procurados, otimizar meu tempo com automação].
#
# **Reflexão:**
# Esse exercício mostrou como a análise de dados pode transformar pequenas tarefas em decisões mais inteligentes no dia a dia.

# %%
# Estudo de Caso: Analisando Vendas Semanais
import pandas as pd
import matplotlib.pyplot as plt

# Dados fictícios de vendas (exemplo do dia a dia)
dados = {
    "Dia": ["Seg", "Ter", "Qua", "Qui", "Sex", "Sáb", "Dom"],
    "Vendas": [20, 35, 30, 25, 50, 70, 40]
}

# Criando DataFrame
df = pd.DataFrame(dados)

# Exibir tabela
print("Tabela de Vendas Semanais:")
print(df)

# Gerar gráfico
plt.figure(figsize=(8,5))
plt.plot(df["Dia"], df["Vendas"], marker="o")
plt.title("Vendas Semanais")
plt.xlabel("Dia da Semana")
plt.ylabel("Quantidade Vendida")
plt.grid(True)
plt.show()
# Out:
# Tabela de Vendas Semanais:
#    Dia  Vendas
# 0  Seg      20
# 1  Ter      35
# 2  Qua      30
# 3  Qui      25
# 4  Sex      50
# 5  Sáb      70
# 6  Dom      40

# %%
# Estudo de Caso: Analisando Engajamento no Instagram
import pandas as pd
import matplotlib.pyplot as plt

# Dados fictícios de posts (exemplo prático do dia a dia)
dados = {
    "Post": ["Post 1", "Post 2", "Post 3", "Post 4", "Post 5"],
    "Curtidas": [120, 340, 230, 150, 400],
    "Comentarios": [15, 40, 25, 10, 60]
}

# Criando DataFrame
df = pd.DataFrame(dados)

# Exibir tabela
print("Tabela de Engajamento dos Posts:")
print(df)

# Gráfico de barras
df.plot(x="Post", y=["Curtidas", "Comentarios"], kind="bar", figsize=(8,5))
plt.title("Engajamento no Instagram")
plt.xlabel("Post")
plt.ylabel("Quantidade")
plt.show()
# Out:
# Tabela de Engajamento dos Posts:
#      Post  Curtidas  Comentarios
# 0  Post 1       120           15
# 1  Post 2       340           40
# 2  Post 3       230           25
# 3  Post 4       150           10
# 4  Post 5       400           60

# %% [markdown]
# #<font color="blue"> 13. Conclusão</font>
#
# A utilização de ferramentas como Python, Pandas e Matplotlib nos estudos de caso mostrou como é possível transformar dados simples do dia a dia em informações valiosas.
#
# No caso das vendas semanais, a visualização em gráfico revelou padrões de maior movimento, auxiliando no planejamento de estoque e promoções. Já no estudo do engajamento no Instagram, a análise de curtidas e comentários trouxe clareza sobre quais conteúdos geram maior impacto, servindo como guia para novas estratégias.
#
# Esses exemplos demonstram que, mesmo em situações rotineiras, a análise de dados é uma poderosa aliada na tomada de decisões mais assertivas, no ganho de eficiência e na geração de insights práticos para os negócios.
